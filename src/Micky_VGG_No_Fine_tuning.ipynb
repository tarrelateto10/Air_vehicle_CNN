# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-d73213ec-1859-21b5-5c0d-81620d03da6a)

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Oct 24 03:11:39 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import sys
print( f"Python {sys.version}\n" )

import os

import numpy as np
print( f"NumPy {np.__version__}\n" )

import pandas as pd
print( f"Pandas {pd.__version__}\n" )

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
print( f"Matplotlib {matplotlib.__version__}\n" )

import tensorflow as tf
print( f"TensorFlow {tf.__version__}" )
print( f"tf.keras.backend.image_data_format() = {tf.keras.backend.image_data_format()}" )

# Count the number of GPUs as detected by tensorflow
gpus = tf.config.list_physical_devices('GPU')
print( f"TensorFlow detected { len(gpus) } GPU(s):" )
for i, gpu in enumerate(gpus):
  print( f".... GPU No. {i}: Name = {gpu.name} , Type = {gpu.device_type}" )
# Out:
# Python 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]
#
# NumPy 1.23.5
#
# Pandas 1.5.3
#
# Matplotlib 3.7.1
#
# TensorFlow 2.14.0
# tf.keras.backend.image_data_format() = channels_last
# TensorFlow detected 1 GPU(s):
# .... GPU No. 0: Name = /physical_device:GPU:0 , Type = GPU

# %%
# Set fixed seeding values for reproducability during experiments
# Skip this cell if random initialization (with varied results) is needed
# np.random.seed(1234)
# tf.random.set_seed(5678)

# %%
# !pip install wandb -qU
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 21.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 18.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.0/241.0 kB 24.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.8 MB/s eta 0:00:00
#   Building wheel for pathtools (setup.py) ... done

# %%
import wandb
print(f'WandB {wandb.__version__}')
# Out:
# WandB 0.15.12

# %%
# !pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0

# %%
# Choose how you want to use WandB

menu = f"Do you have an environment variable named 'WANDB_API_KEY' stored in .env file?\nYour answer (y/n): "
while True:
  choice = input(menu).lower().strip()

  if choice == 'y':
    # Load 'WANDB_API_KEY' from the ".env" file
    from dotenv import load_dotenv
    load_dotenv('/content/env')
    WANDB_API_KEY = os.getenv('WANDB_API_KEY')
    # print(WANDB_API_KEY)
    # Login with your WandB account
    wandb.login(key=WANDB_API_KEY)
    break

  elif choice == 'n':
    # Login as anonymous (no need for API key)
    wandb.login(anonymous='allow')
    break

  else:
    print('Invalid input. Try again.\n')
# Out:
# Do you have an environment variable named 'WANDB_API_KEY' stored in .env file?
# Your answer (y/n): y
# wandb: Currently logged in as: mrravit (deep-a). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# **LOAD DATA**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Colab Notebooks/datasets/data.zip"
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
#   inflating: data/planes/drone/00000126.jpg
#   inflating: __MACOSX/data/planes/drone/._00000126.jpg
#   inflating: data/planes/drone/00000132.jpg
#   inflating: __MACOSX/data/planes/drone/._00000132.jpg
#   inflating: data/planes/drone/00000318.png
#   inflating: __MACOSX/data/planes/drone/._00000318.png
#   inflating: data/planes/drone/00000683.jpg
#   inflating: __MACOSX/data/planes/drone/._00000683.jpg
#   inflating: data/planes/drone/00000708.jpg
#   inflating: __MACOSX/data/planes/drone/._00000708.jpg
#   inflating: data/planes/drone/00000087.jpeg
#   inflating: __MACOSX/data/planes/drone/._00000087.jpeg
#   inflating: data/planes/drone/00000052.jpg
#   inflating: __MACOSX/data/planes/drone/._00000052.jpg
#   inflating: data/planes/drone/00000046.jpg
#   inflating: __MACOSX/data/planes/drone/._00000046.jpg
#   inflating: data/planes/drone/00000720.jpg
#   inflating: __MACOSX/data/planes/drone/._00000720.jpg
#   inflating: data/planes/drone/00001100.jpeg
#   inflating: __MACOSX/data/planes/drone/._00001100.jpeg
#   inflating: data/planes/drone/00000711.jpeg
#   inflating: __MACOSX/data/planes/drone/._00
jpg
#   inflating: __MACOSX/data/planes/rocket/._00000356.jpg
#   inflating: data/planes/rocket/00000418.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000418.jpg
#   inflating: data/planes/rocket/00000140.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000140.jpg
#   inflating: data/planes/rocket/00000154.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000154.jpg
#   inflating: data/planes/rocket/00000168.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000168.jpg
#   inflating: data/planes/rocket/00000197.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000197.jpg
#   inflating: data/planes/rocket/00000034.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000034.jpg
#   inflating: data/planes/rocket/00000020.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000020.jpg
#   inflating: data/planes/rocket/00000008.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000008.jpg
#   inflating: data/planes/rocket/00000544.JPG
#   inflating: __MACOSX/data/planes/rocket/._00000544.JPG
#   inflating: data/planes/rocket/00000222.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000222.jpg
#   inflating: data/planes/rocket/00000578.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000578.jpg
#   inflating: data/planes/rocket/00000593.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000593.jpg
#   inflating: data/planes/rocket/00000587.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000587.jpg
#   inflating: data/planes/rocket/00000586.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000586.jpg
#   inflating: data/planes/rocket/00000592.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000592.jpg
#   inflating: data/planes/rocket/00000579.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000579.jpg
#   inflating: data/planes/rocket/00000545.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000545.jpg
#   inflating: data/planes/rocket/00000223.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000223.jpg
#   inflating: data/planes/rocket/00000009.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000009.jpg
#   inflating: data/planes/rocket/00000035.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000035.jpg
#   inflating: data/planes/rocket/00000196.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000196.jpg
#   inflating: data/planes/rocket/00000182.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000182.jpg
#   inflating: data/planes/rocket/00000169.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000169.jpg
#   inflating: data/planes/rocket/00000155.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000155.jpg
#   inflating: data/planes/rocket/00000394.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000394.jpg
#   inflating: data/planes/rocket/00000419.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000419.jpg
#   inflating: data/planes/rocket/00000431.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000431.jpg
#   inflating: data/planes/rocket/00000357.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000357.jpg
#   inflating: data/planes/rocket/00000343.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000343.jpg
#   inflating: data/planes/rocket/00000425.jpg
#   inflating: __MACOSX/data/planes/rocket/._00000425.jpg

# %%
import os
import cv2
import numpy as np

# ตั้งค่าพารามิเตอร์
dataset_folder = "/content/data/planes"
img_size = (224, 224)  # ขนาดที่คุณต้องการ resize รูป

x_train = []
y_train = []

# วนลูปตามโฟลเดอร์ย่อยภายในโฟลเดอร์ planes
for class_folder in os.listdir(dataset_folder):
    class_path = os.path.join(dataset_folder, class_folder)

    if os.path.isdir(class_path):
        for filename in os.listdir(class_path):
            img_path = os.path.join(class_path, filename)

            # อ่านรูปภาพ
            img = cv2.imread(img_path, cv2.IMREAD_COLOR)

            # Check if the image was loaded successfully
            if img is None:
                print(f"Warning: Image not loaded for file: {img_path}")
                continue

            # img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert จาก BGR เป็น RGB
            img = cv2.resize(img, img_size)

            x_train.append(img)
            y_train.append(class_folder)  # ใช้ชื่อโฟลเดอร์เป็น label
# Out:
# Warning: Image not loaded for file: /content/data/planes/drone/.DS_Store
# Warning: Image not loaded for file: /content/data/planes/helicopter/.DS_Store
# Warning: Image not loaded for file: /content/data/planes/fighter-jet/.DS_Store
# Warning: Image not loaded for file: /content/data/planes/rocket/.DS_Store
# Warning: Image not loaded for file: /content/data/planes/passenger-plane/.DS_Store

# %% [markdown]
# **CONVERT DATA**

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
print(x_train.shape)
print(y_train.shape)
# Out:
# (3853, 224, 224, 3)
# (3853,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test = train_test_split(x_train, test_size = 0.2, random_state = 1)
y_train, y_test = train_test_split(y_train, test_size = 0.2, random_state = 1)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3082, 224, 224, 3)
# (3082,)
# (771, 224, 224, 3)
# (771,)

# %%
unique_labels = np.unique(y_train)
label_to_int = {label: i for i, label in enumerate(unique_labels)}

y_train = np.array([label_to_int[label] for label in y_train])
y_test = np.array([label_to_int[label] for label in y_test])

# %%
print( f"x_train: type={type(x_train)} , dtype={x_train.dtype} , shape={x_train.shape} , min={x_train.min(axis=None)} , max={x_train.max(axis=None)}" )
print( f"y_train: type={type(y_train)} , dtype={y_train.dtype} , shape={y_train.shape} , min={min(y_train)} , max={max(y_train)}" )
print( f"x_test: type={type(x_test)} , dtype={x_test.dtype} , shape={x_test.shape} , min={x_test.min(axis=None)} , max={x_test.max(axis=None)}"  )
print( f"y_test: type={type(y_test)} , dtype={y_test.dtype} , shape={y_test.shape} , min={min(y_test)} , max={max(y_test)}" )
# Out:
# x_train: type=<class 'numpy.ndarray'> , dtype=uint8 , shape=(3082, 224, 224, 3) , min=0 , max=255
# y_train: type=<class 'numpy.ndarray'> , dtype=int64 , shape=(3082,) , min=0 , max=4
# x_test: type=<class 'numpy.ndarray'> , dtype=uint8 , shape=(771, 224, 224, 3) , min=0 , max=255
# y_test: type=<class 'numpy.ndarray'> , dtype=int64 , shape=(771,) , min=0 , max=4

# %%
x_train = x_train.astype('uint8')
x_test = x_test.astype('uint8')
y_train = y_train.astype('float32')
y_test = y_test.astype('float32')

# %%
print( f"x_train: type={type(x_train)} , dtype={x_train.dtype} , shape={x_train.shape} , min={x_train.min(axis=None)} , max={x_train.max(axis=None)}" )
print( f"y_train: type={type(y_train)} , dtype={y_train.dtype} , shape={y_train.shape} , min={min(y_train)} , max={max(y_train)}" )
print( f"x_test: type={type(x_test)} , dtype={x_test.dtype} , shape={x_test.shape} , min={x_test.min(axis=None)} , max={x_test.max(axis=None)}"  )
print( f"y_test: type={type(y_test)} , dtype={y_test.dtype} , shape={y_test.shape} , min={min(y_test)} , max={max(y_test)}" )
# Out:
# x_train: type=<class 'numpy.ndarray'> , dtype=uint8 , shape=(3082, 224, 224, 3) , min=0 , max=255
# y_train: type=<class 'numpy.ndarray'> , dtype=float32 , shape=(3082,) , min=0.0 , max=4.0
# x_test: type=<class 'numpy.ndarray'> , dtype=uint8 , shape=(771, 224, 224, 3) , min=0 , max=255
# y_test: type=<class 'numpy.ndarray'> , dtype=float32 , shape=(771,) , min=0.0 , max=4.0

# %%
plt.figure(figsize=(15,5))
for i in range(5):
    plt.subplot(150 + 1 + i).set_title( f"class no. {y_train[i]}: " )
    plt.imshow( x_train[i] )
    #plt.axis( "off" )
plt.show()

# %%
#visualize the first 5 image of x_train
label = ['drone', 'fighter-jet', 'helicopter', 'passenger-plane', 'rocket']

plt.figure(figsize = (15,5))
for i in range(5):
  plt.subplot(150 + 1 + i).set_title(f'class {int(y_train[i])} ({label[int(y_train[i])]})')
  plt.imshow(x_train[i])
plt.show()

# %%
plt.figure(figsize=(15,5))

for i in range(5):
    class_index = int(y_test[i])  # Cast the value to integer
    class_name = label[class_index]
    plt.subplot(150 + 1 + i).set_title(f'class {class_index} ({class_name})')
    plt.imshow(x_test[i])
    plt.axis('off')  # Hide axis for better visualization

plt.show()

# %% [markdown]
# **LOAD MODEL**

# %%
img_w,img_h = 224, 224
vgg_extractor = tf.keras.applications.vgg16.VGG16(weights = "imagenet", include_top=False, input_shape = (img_w, img_h, 3))

vgg_extractor.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(vgg_extractor, 'VGG16_Model.png', show_shapes=True,show_layer_names=True)

# %%
#Recursively freeze all layers in the model first
vgg_extractor.trainable = False

for i, layer in enumerate(vgg_extractor.layers):
  print(f'Layer {i}: Name = {layer.name}, Trainable = {layer.trainable}')
# Out:
# Layer 0: Name = input_1, Trainable = False
# Layer 1: Name = block1_conv1, Trainable = False
# Layer 2: Name = block1_conv2, Trainable = False
# Layer 3: Name = block1_pool, Trainable = False
# Layer 4: Name = block2_conv1, Trainable = False
# Layer 5: Name = block2_conv2, Trainable = False
# Layer 6: Name = block2_pool, Trainable = False
# Layer 7: Name = block3_conv1, Trainable = False
# Layer 8: Name = block3_conv2, Trainable = False
# Layer 9: Name = block3_conv3, Trainable = False
# Layer 10: Name = block3_pool, Trainable = False
# Layer 11: Name = block4_conv1, Trainable = False
# Layer 12: Name = block4_conv2, Trainable = False
# Layer 13: Name = block4_conv3, Trainable = False
# Layer 14: Name = block4_pool, Trainable = False
# Layer 15: Name = block5_conv1, Trainable = False
# Layer 16: Name = block5_conv2, Trainable = False
# Layer 17: Name = block5_conv3, Trainable = False
# Layer 18: Name = block5_pool, Trainable = False

# %% [markdown]
# **PRE PROCESSING DATA**

# %%
#Pre-processing
x_train_vgg =  tf.keras.applications.vgg16.preprocess_input(x_train)
x_test_vgg = tf.keras.applications.vgg16.preprocess_input(x_test)

print(x_train_vgg.shape)
print(x_test_vgg.shape)
# Out:
# (3082, 224, 224, 3)
# (771, 224, 224, 3)

# %% [markdown]
# **DATA AUGMENT**

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        #rescale=1. / 255,
        #featurewise_center=True,
        samplewise_center=True,
        #featurewise_std_normalization=True,
        samplewise_std_normalization=True,
        #zca_whitening=False,
        rotation_range=0,
        width_shift_range=5.0,
        height_shift_range=5.0,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        validation_split=0.3)
train_datagen.fit(x_train_vgg)

# %%
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        #rescale=1. / 255,
        # featurewise_center=True,
        samplewise_center=True,
        # featurewise_std_normalization=True,
        samplewise_std_normalization=True
        )
test_datagen.fit(x_test_vgg)

# %%
n_show = 1    # show 'n_show' batches of generated data (1 batch includes 5 images)

for b, (x_batch, y_batch) in enumerate( train_datagen.flow( x_train, y_train, batch_size=5, subset='training' ) ):
  print( f"===== Train batch no. {b+1}/{n_show} =====" )
  plt.figure(figsize=(15,5))
  for i in range(5):
      plt.subplot(150 + 1 + i).set_title( y_batch[i] )
      plt.imshow( x_batch[i])
      plt.axis( "off" )        # remove all tick marks
  plt.show()

  if b+1 >= n_show:
    break
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ===== Train batch no. 1/1 =====

# %%
n_show = 1    # show 'n_show' batches of generated data (1 batch includes 5 images)

for b, (x_batch, y_batch) in enumerate( train_datagen.flow( x_train, y_train, batch_size=5, subset='validation' ) ):
  print( f"===== Train batch no. {b+1}/{n_show} =====" )
  plt.figure(figsize=(15,5))
  for i in range(5):
      plt.subplot(150 + 1 + i).set_title( y_batch[i] )
      plt.imshow( x_batch[i])
      plt.axis( "off" )        # remove all tick marks
  plt.show()

  if b+1 >= n_show:
    break
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ===== Train batch no. 1/1 =====

# %%
x = vgg_extractor.output

#Add our custom layer(s) to the end of the existing model
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(512, activation = 'relu')(x)
x = tf.keras.layers.Dense(256, activation = 'relu')(x)
x = tf.keras.layers.Dense(128, activation = 'relu')(x)
x = tf.keras.layers.Dense(64, activation = 'relu')(x)

x = tf.keras.layers.Dropout(0.5)(x)
new_outputs = tf.keras.layers.Dense(5, activation = 'softmax')(x)

#construct the main model
model = tf.keras.models.Model(inputs = vgg_extractor.inputs, outputs = new_outputs)

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_5 (Dense)             (None, 512)               12845568
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 27733061 (105.79 MB)
# Trainable params: 13018373 (49.66 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# **TRAIN & EVALUATE**

# %%
from tensorflow.keras.optimizers import Adam
from traitlets import validate

optimizer = Adam(learning_rate=0.001)

model.compile( loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["acc"] )

# %%
print(y_train.shape)
print(y_train.dtype)
# Out:
# (3082,)
# float32

# %%
num_classes = len(np.unique(y_train))
print(num_classes)
# Out:
# 5

# %%
y_train[0:10]
# Out:
# array([3., 3., 2., 2., 0., 3., 2., 1., 3., 2.], dtype=float32)

# %%
from wandb.keras import WandbCallback
wandb.init(project='Micky_VGG_No_Fine_tuning', entity='deep-a')
# Out:
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231024_035516-c4ulaaxt</code>
# Syncing run <strong><a href='https://wandb.ai/deep-a/Micky_vgg_No_fine_tuning/runs/c4ulaaxt' target="_blank">radiant-mountain-1</a></strong> to <a href='https://wandb.ai/deep-a/Micky_vgg_No_fine_tuning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/deep-a/Micky_vgg_No_fine_tuning' target="_blank">https://wandb.ai/deep-a/Micky_vgg_No_fine_tuning</a>
#  View run at <a href='https://wandb.ai/deep-a/Micky_vgg_No_fine_tuning/runs/c4ulaaxt' target="_blank">https://wandb.ai/deep-a/Micky_vgg_No_fine_tuning/runs/c4ulaaxt</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/deep-a/Micky_vgg_No_fine_tuning/runs/c4ulaaxt?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
history = model.fit(train_datagen.flow(x_train_vgg ,y_train,batch_size=32,subset='training'),epochs = 20, verbose = 2,
                    validation_data=train_datagen.flow(x_train_vgg ,y_train,batch_size=32,subset='validation'),
                    callbacks=[WandbCallback()])
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# wandb: Adding directory to artifact (/content/wandb/run-20231024_035516-c4ulaaxt/files/model-best)... Done. 2.1s
# 68/68 - 42s - loss: 1.2878 - acc: 0.5051 - val_loss: 0.6856 - val_acc: 0.7630 - 42s/epoch - 619ms/step
# Epoch 2/20
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# wandb: Adding directory to artifact (/content/wandb/run-20231024_035516-c4ulaaxt/files/model-best)... Done. 0.7s
# 68/68 - 40s - loss: 0.7298 - acc: 0.7322 - val_loss: 0.5369 - val_acc: 0.8019 - 40s/epoch - 591ms/step
# Epoch 3/20
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# wandb: Adding directory to artifact (/content/wandb/run-20231024_035516-c4ulaaxt/files/model-best)... Done. 0.7s
# 68/68 - 40s - loss: 0.5592 - acc: 0.8017 - val_loss: 0.4337 - val_acc: 0.8517 - 40s/epoch - 583ms/step
# Epoch 4/20
# 68/68 - 36s - loss: 0.4561 - acc: 0.8536 - val_loss: 0.4653 - val_acc: 0.8431 - 36s/epoch - 528ms/step
# Epoch 5/20
# 68/68 - 35s - loss: 0.3284 - acc: 0.8906 - val_loss: 0.4870 - val_acc: 0.8615 - 35s/epoch - 520ms/step
# Epoch 6/20
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# wandb: Adding directory to artifact (/content/wandb/run-20231024_035516-c4ulaaxt/files/model-best)... Done. 0.6s
# 68/68 - 39s - loss: 0.3471 - acc: 0.8906 - val_loss: 0.4127 - val_acc: 0.8626 - 39s/epoch - 577ms/step
# Epoch 7/20
# 68/68 - 35s - loss: 0.3069 - acc: 0.9050 - val_loss: 0.4178 - val_acc: 0.8745 - 35s/epoch - 520ms/step
# Epoch 8/20
# 68/68 - 36s - loss: 0.2673 - acc: 0.9157 - val_loss: 0.4569 - val_acc: 0.8593 - 36s/epoch - 523ms/step
# Epoch 9/20
# 68/68 - 36s - loss: 0.2399 - acc: 0.9226 - val_loss: 0.5917 - val_acc: 0.8582 - 36s/epoch - 525ms/step
# Epoch 10/20
# 68/68 - 36s - loss: 0.2233 - acc: 0.9310 - val_loss: 0.4824 - val_acc: 0.8485 - 36s/epoch - 536ms/step
# Epoch 11/20
# 68/68 - 35s - loss: 0.2173 - acc: 0.9328 - val_loss: 0.4675 - val_acc: 0.8658 - 35s/epoch - 520ms/step
# Epoch 12/20
# 68/68 - 35s - loss: 0.2075 - acc: 0.9351 - val_loss: 0.5039 - val_acc: 0.8669 - 35s/epoch - 514ms/step
# Epoch 13/20
# 68/68 - 35s - loss: 0.1510 - acc: 0.9504 - val_loss: 0.5670 - val_acc: 0.8658 - 35s/epoch - 521ms/step
# Epoch 14/20
# 68/68 - 36s - loss: 0.1558 - acc: 0.9564 - val_loss: 0.5687 - val_acc: 0.8636 - 36s/epoch - 525ms/step
# Epoch 15/20
# 68/68 - 36s - loss: 0.1861 - acc: 0.9402 - val_loss: 0.4836 - val_acc: 0.8734 - 36s/epoch - 524ms/step
# Epoch 16/20
# 68/68 - 36s - loss: 0.1092 - acc: 0.9671 - val_loss: 0.6603 - val_acc: 0.8626 - 36s/epoch - 526ms/step
# Epoch 17/20
# 68/68 - 35s - loss: 0.1246 - acc: 0.9615 - val_loss: 0.7328 - val_acc: 0.8658 - 35s/epoch - 518ms/step
# Epoch 18/20
# 68/68 - 36s - loss: 0.1278 - acc: 0.9597 - val_loss: 0.6909 - val_acc: 0.8777 - 36s/epoch - 529ms/step
# Epoch 19/20
# 68/68 - 36s - loss: 0.0988 - acc: 0.9727 - val_loss: 0.7463 - val_acc: 0.8452 - 36s/epoch - 525ms/step
# Epoch 20/20
# 68/68 - 36s - loss: 0.1413 - acc: 0.9578 - val_loss: 0.6262 - val_acc: 0.8561 - 36s/epoch - 523ms/step

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1027.470 MB of 1027.470 MB uploaded (0.178 MB deduped)\r'), FloatProgress(value=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▁▄▅▆▇▇▇▇▇▇▇▇████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▅▄▃▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▃▆▆▇▇█▇▇▆▇▇▇▇█▇▇█▆▇</td></tr><tr><td>val_loss</td><td>▇▄▁▂▃▁▁▂▅▂▂▃▄▄▂▆█▇█▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>0.95783</td></tr><tr><td>best_epoch</td><td>5</td></tr><tr><td>best_val_loss</td><td>0.4127</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.14126</td></tr><tr><td>val_acc</td><td>0.85606</td></tr><tr><td>val_loss</td><td>0.62623</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">radiant-mountain-1</strong> at: <a href='https://wandb.ai/deep-a/Micky_vgg_No_fine_tuning/runs/c4ulaaxt' target="_blank">https://wandb.ai/deep-a/Micky_vgg_No_fine_tuning/runs/c4ulaaxt</a><br/>Synced 5 W&B file(s), 0 media file(s), 20 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231024_035516-c4ulaaxt/logs</code>

# %%
results = model.evaluate(test_datagen.flow(x_test_vgg, y_test, batch_size = 128))
print(f'{model.metrics_names}: {results}')
# Out:
# 7/7 [==============================] - 3s 413ms/step - loss: 0.4145 - acc: 0.8898
# ['loss', 'acc']: [0.4145070016384125, 0.8897535800933838]

# %%
#Summarize history of accuracy
plt.figure(figsize = (15,5))
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Train accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc = 'upper left')
plt.grid()
plt.show()

# %%
#Summarize history for loss
plt.figure(figsize = (15,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Train loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc = 'upper right')
plt.grid()
plt.show()

# %%
plt.rcParams["axes.linewidth"] = 5

def color_frame( ax, y_true, y_pred ):
  color = 'green' if (y_true == y_pred) else 'red'
  ax.spines['bottom'].set_color(color)
  ax.spines['top'].set_color(color)
  ax.spines['right'].set_color(color)
  ax.spines['left'].set_color(color)

# %%
# Test using the model on many images


# Get a batch of samples
n = 10
samples = x_test[:n]
print(f'{samples.shape=}')

# Predict a batch of samples
y_pred = model.predict(samples)

# Interpret the results
for i in range(n):
  plt.figure(figsize=(3,3), dpi=90)
  ax = plt.gca()
  plt.imshow( x_test[i] )
  plt.title(f" pred={np.argmax(y_pred[i])}")
  color_frame(ax, y_test[i], np.argmax(y_pred[i]))
  plt.show()
# Out:
# samples.shape=(10, 224, 224, 3)
# 1/1 [==============================] - 2s 2s/step

# %% [markdown]
# **GRAD-CAM**

# %%
import keras

img_size = (224, 224)
preprocess_input = keras.applications.vgg16.preprocess_input
last_conv_layer_name = "block5_pool"

# %%
from IPython.display import Image, display
import matplotlib.cm as cmp


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    grad_model = tf.keras.models.Model([model.inputs], [model.get_layer(last_conv_layer_name).output, model.output])
    with tf.GradientTape() as tape:
          last_conv_layer_output, preds = grad_model(img_array)
          if pred_index is None:
              pred_index = tf.argmax(preds[0])
          class_channel = preds[:, pred_index]
    grads = tape.gradient(class_channel, last_conv_layer_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.8):
      img = img_path

      # Rescale heatmap to a range 0-255
      heatmap = np.uint8(255 * heatmap)

      # Use jet colormap to colorize heatmap
      jet = plt.get_cmap("jet")

      # Use RGB values of the colormap
      jet_colors = jet(np.arange(256))[:, :3]
      jet_heatmap = jet_colors[heatmap]

      # Create an image with RGB colorized heatmap
      jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
      jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
      jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

      # Superimpose the heatmap on original image
      superimposed_img = jet_heatmap * alpha + img
      superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

      # Save the superimposed image
      superimposed_img.save(cam_path)

      # Display Grad CAM
      display(Image(cam_path))

for i in range(5):
  c= np.random.randint(0,180)
  img_path = x_test[c]
  img_array = preprocess_input(img_path)
  model.layers[-1].activation = None
  preds = model.predict(img_array.reshape(-1,224,224,3))
  print(f"Predicted: {label[int(np.argmax(preds))]} | Actual: {label[int(y_test[c])]} ")
  heatmap = make_gradcam_heatmap(img_array.reshape(1,224,224,3), model, last_conv_layer_name)
  save_and_display_gradcam(img_path, heatmap)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# Predicted: rocket | Actual: rocket
# 1/1 [==============================] - 0s 22ms/step
# Predicted: helicopter | Actual: helicopter
# 1/1 [==============================] - 0s 23ms/step
# Predicted: passenger-plane | Actual: helicopter
# 1/1 [==============================] - 0s 23ms/step
# Predicted: drone | Actual: drone
# 1/1 [==============================] - 0s 23ms/step
# Predicted: passenger-plane | Actual: passenger-plane
